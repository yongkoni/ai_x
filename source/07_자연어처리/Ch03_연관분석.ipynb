# %%
from IPython.display import display, HTML
display(HTML("""<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{fontsize:12pt;padding:5px;}
table.dataframe{font-size:12px;}))
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{fontsize:12pt;padding:5px;}
# table.dataframe{font-size:12px;}))
# </style>

# %% [markdown]
# # <span style = "color:red">ch3 연관분석</span>

# %% [markdown]
# # 1. 연관분석 개요
#
# - pip install apyori
# - 데이터들 사이에 자주 발생하는 속성을 찾고, 그 속성들 사이에 연관성이 어느 정도 있는지 분석
# - 활용분야 : 이벤트 미리 감지 (사기 적발...), 신상품 카테고리 구성
#
# [조건:left-hand side:오렌지주스] → [결과:right-hand side:와인]
# ```
# - 연관분석과 관련된 지표
# 1. 지지도(support) : 얼마나 자주 함께 나타나는지
#     (lhs, rhs)의 항목수 / 전체 항목수 = 0.2
#
# 2. 신뢰도(confidence) : 조건이 오면 결과가 얼마나 자주 나타나는지
#     (lhs → rhs)의 항목수 / 전체 항목수 = 1 / 2 = 0.5
#
# 3. 향상도(lift) : 우연히 발생한 규칙은 아닌지 확인
#     (lhs → rhs)의 지지도 / (lhs의 지지도 * rhs의 지지도)
#     → 0.2 / (0.4 * 0.6) = 0.2 / 0.24 = 0.833
#     향상도 < 1 : 기대가 낮다
#     향상도 > 1 : 기대가 높다
# ```

# %% [markdown]
# # 2. 연관분석 구현

# %%
import csv

with open('data/cf_basket.csv', 'r', encoding='utf-8') as f :
    csvdata = csv.reader(f)
    # print(list(csvdata))
    transaction = list(csvdata)
transaction
# Out:
# [['소주', '콜라', '와인'],
#  ['소주', '오렌지주스', '콜라'],
#  ['맥주', '콜라', '와인'],
#  ['소주', '콜라', '맥주'],
#  ['오렌지주스', '와인']]

# %%
from apyori import apriori

rules = apriori(transaction,  # 2차원 데이터
               min_support = 0.15,
               min_confidence = 0.1)
rules = list(rules)
len(rules)
# Out:
# 18

# %%
rules[10]
# Out:
# RelationRecord(items=frozenset({'소주', '콜라'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'소주', '콜라'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'소주'}), items_add=frozenset({'콜라'}), confidence=1.0, lift=1.25), OrderedStatistic(items_base=frozenset({'콜라'}), items_add=frozenset({'소주'}), confidence=0.7499999999999999, lift=1.2499999999999998)])

# %%
rule = rules[10]
support = rule[1]
order_st = rule[2]
for item in order_st :
    lhs = item[0]
    rhs = item[1]
    confidence = item[2]
    lift = item[3]
    if lift > 1 :
        print("{} → {}\t {}\t {}\t {}".format(lhs, rhs, support, 
                                             round(confidence, 2), 
                                             round(lift, 2)))
# Out:
# frozenset({'소주'}) → frozenset({'콜라'})	 0.6	 1.0	 1.25
# frozenset({'콜라'}) → frozenset({'소주'})	 0.6	 0.75	 1.25

# %%
for rule in rules :
    support = rule[1]
    order_st = rule[2]
    for item in order_st :
        lhs = item[0]
        rhs = item[1]
        confidence = item[2]
        lift = item[3]
        if lift > 1 :
            print("{} → {}\t {}\t {}\t {}".format(lhs, rhs, support, 
                                                 round(confidence, 2), 
                                                 round(lift, 2)))
# Out:
# frozenset({'맥주'}) → frozenset({'콜라'})	 0.4	 1.0	 1.25
# frozenset({'콜라'}) → frozenset({'맥주'})	 0.4	 0.5	 1.25
# frozenset({'소주'}) → frozenset({'콜라'})	 0.6	 1.0	 1.25
# frozenset({'콜라'}) → frozenset({'소주'})	 0.6	 0.75	 1.25
# frozenset({'콜라'}) → frozenset({'맥주', '소주'})	 0.2	 0.25	 1.25
# frozenset({'맥주', '소주'}) → frozenset({'콜라'})	 0.2	 1.0	 1.25
# frozenset({'맥주'}) → frozenset({'와인', '콜라'})	 0.2	 0.5	 1.25
# frozenset({'콜라'}) → frozenset({'맥주', '와인'})	 0.2	 0.25	 1.25
# frozenset({'맥주', '와인'}) → frozenset({'콜라'})	 0.2	 1.0	 1.25
# frozenset({'와인', '콜라'}) → frozenset({'맥주'})	 0.2	 0.5	 1.25
# frozenset({'소주'}) → frozenset({'오렌지주스', '콜라'})	 0.2	 0.33	 1.67
# frozenset({'콜라'}) → frozenset({'소주', '오렌지주스'})	 0.2	 0.25	 1.25
# frozenset({'소주', '오렌지주스'}) → frozenset({'콜라'})	 0.2	 1.0	 1.25
# frozenset({'오렌지주스', '콜라'}) → frozenset({'소주'})	 0.2	 1.0	 1.67
# frozenset({'콜라'}) → frozenset({'소주', '와인'})	 0.2	 0.25	 1.25
# frozenset({'소주', '와인'}) → frozenset({'콜라'})	 0.2	 1.0	 1.25

# %%
import pandas as pd

rules_df = pd.DataFrame(None, columns = ['lhs', 'rhs', '지지도', '신뢰도', '향상도'])
# rules_df.loc[0] = ['와인', '오렌지', 0.15, 0.5, 1.1] 식으로 for문내에서 데이터추가
idx = 0
for rule in rules :
    support = rule[1]
    order_st = rule[2]
    for item in order_st :
        lhs = ', '.join([data for data in item[0]])
        rhs = ', '.join([data for data in item[1]])
        confidence = item[2]
        lift = item[3]
        if lift > 1 :
            rules_df.loc[idx] = [lhs, rhs, support, round(confidence, 2), round(lift, 2)]
            idx += 1
rules_df.sort_values(by=['향상도', '신뢰도'], ascending = False)
# Out:
#           lhs        rhs  지지도   신뢰도   향상도
# 13  오렌지주스, 콜라         소주  0.2  1.00  1.67
# 10         소주  오렌지주스, 콜라  0.2  0.33  1.67
# 0          맥주         콜라  0.4  1.00  1.25
# 2          소주         콜라  0.6  1.00  1.25
# 5      맥주, 소주         콜라  0.2  1.00  1.25
# 8      맥주, 와인         콜라  0.2  1.00  1.25
# 12  소주, 오렌지주스         콜라  0.2  1.00  1.25
# 15     소주, 와인         콜라  0.2  1.00  1.25
# 3          콜라         소주  0.6  0.75  1.25
# 1          콜라         맥주  0.4  0.50  1.25
# 6          맥주     와인, 콜라  0.2  0.50  1.25
# 9      와인, 콜라         맥주  0.2  0.50  1.25
# 4          콜라     맥주, 소주  0.2  0.25  1.25
# 7          콜라     맥주, 와인  0.2  0.25  1.25
# 11         콜라  소주, 오렌지주스  0.2  0.25  1.25
# 14         콜라     소주, 와인  0.2  0.25  1.25

# %% [markdown]
# # 3. 경주 / 전주 여행 자료 연관분석

# %%
import pandas as pd
from konlpy.tag import Hannanum

df = pd.read_csv('data/naver_kin.csv', sep = '\t')
total_text_list = df['total_text'].to_list()
# total_text_list[:2]
analyzer = Hannanum()
total_noun_list = []
select_pos = ['NC', 'NQ']  # 보통명사, 고유명사
불용어 = {'여행'}
for total_text in total_text_list :
    # total_noun = analyzer.nouns(total_text)
    total_noun = [token for token, tag in analyzer.pos(total_text, ntags = 22)
                     if tag in select_pos 
                      and token not in 불용어
                         and len(token) > 1]
    total_noun_list.append(total_noun)
print(total_noun_list[:2])
# Out:
# [['전주', '가볼만한곳', '추천', '추억', '다양한체험', '7080감성', '추억여행', '테마박물관', '유익한시간', '전북투어패스', '통합이용권', '전북핫플', '여러여행지', '다양한체험', '카페이용추', '전주여행', '편안', '되시길', '감사'], ['전주여행', '전주여행', '아는사람', '호텔', '좋은가격', '2박3일여행인데', '얼마정도갖고가면좋을까요', '맛집같은거', '카페같은거', '추천', '안녕', '전주', '계획', '한옥마을', '근처']]

# %%
import pandas as pd
from konlpy.tag import Kkma

df = pd.read_csv('data/naver_kin.csv', sep = '\t')
total_text_list = df['total_text'].to_list()
# total_text_list[:2]
analyzer = Kkma()
total_noun_list = []
# select_pos = ['NC', 'NQ']  # 보통명사, 고유명사
select_pos = ['NNP', 'NNG']  # 보통명사, 고유명사
불용어 = {'여행'}
for total_text in total_text_list :
    # total_noun = analyzer.nouns(total_text)
    total_noun = [token for token, tag in analyzer.pos(total_text)
                     if tag in select_pos 
                      and token not in 불용어
                         and len(token) > 1]
    total_noun_list.append(total_noun)
print(total_noun_list[:2])
# Out:
# [['전주', '추천', '추억', '다양', '체험', '추억', '테마', '박물관', '유익', '시간', '투어', '패스', '통합', '이용권', '여행지', '다양', '체험', '카페', '이용', '추가', '전주', '필수', '편안', '감사'], ['전주', '전주', '사람', '호텔', '가격', '얼마', '정도', '카페', '추천', '주세', '안녕', '하세', '전주', '계획', '중이', '한옥', '마을', '근처']]

# %%
import pandas as pd
from konlpy.tag import Komoran

df = pd.read_csv('data/naver_kin.csv', sep = '\t')
total_text_list = df['total_text'].to_list()
# total_text_list[:2]
analyzer = Komoran()
total_noun_list = []
# select_pos = ['NC', 'NQ']  # 보통명사, 고유명사
select_pos = ['NNP', 'NNG']  # 보통명사, 고유명사
불용어 = {'여행'}
for total_text in total_text_list :
    # total_noun = analyzer.nouns(total_text)
    total_noun = [token for token, tag in analyzer.pos(total_text)
                     if tag in select_pos 
                      and token not in 불용어
                         and len(token) > 1]
    total_noun_list.append(total_noun)
print(total_noun_list[:2])
# Out:
# [['전주', '한곳', '추천', '추억', '체험', '감성', '추억', '테마', '박물관', '시간', '전북', '전북', '투어', '패스', '통합', '이용', '여행지', '체험', '카페', '이용', '추가', '전주', '필수', '편안', '감사'], ['전주', '전주', '사람과', '호텔', '가격', '얼마', '정도', '맛집', '카페', '추천', '안녕하세요', '전주', '계획', '한옥마을', '근처']]

# %%
# %%time

rules = apriori(total_noun_list, min_support = 0.15, min_confidence = 0.3)
rules = list(rules)
len(rules)
# Out:
# CPU times: total: 78.1 ms
# Wall time: 85.8 ms
# 193

# %%
import pandas as pd

rules_df = pd.DataFrame(None, columns = ['lhs', 'rhs', '지지도', '신뢰도', '향상도'])
idx = 0
for rule in rules :
    support = rule[1]
    order_st = rule[2]
    for item in order_st :
        lhs = ', '.join([data for data in item[0]])
        rhs = ', '.join([data for data in item[1]])
        confidence = item[2]
        lift = item[3]
        if lift > 1 :
            rules_df.loc[idx] = [lhs, rhs, support, round(confidence, 2), round(lift, 2)]
            idx += 1
rules_df.sort_values(by=['향상도', '신뢰도'], ascending = False, inplace = True)
rules_df = rules_df.reset_index(drop = True)

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
rules_df.head(60)
# Out:
#            lhs         rhs    지지도  신뢰도   향상도
# 0          제주도      맛집, 여수  0.152  1.0  5.99
# 1          제주도      주가, 여수  0.152  1.0  5.99
# 2          제주도      코스, 여수  0.152  1.0  5.99
# 3          제주도      한곳, 여수  0.152  1.0  5.99
# 4       주가, 국내      맛집, 여수  0.157  1.0  5.99
# 5       한곳, 국내      맛집, 여수  0.157  1.0  5.99
# 6       주가, 국내      코스, 여수  0.157  1.0  5.99
# 7       주가, 국내      한곳, 여수  0.157  1.0  5.99
# 8       한곳, 국내      주가, 여수  0.157  1.0  5.99
# 9       한곳, 국내      코스, 여수  0.157  1.0  5.99
# 10         제주도  맛집, 여수, 전주  0.152  1.0  5.99
# 11     제주도, 전주      맛집, 여수  0.152  1.0  5.99
# 12         제주도  주가, 맛집, 여수  0.152  1.0  5.99
# 13     맛집, 제주도      주가, 여수  0.152  1.0  5.99
# 14     주가, 제주도      맛집, 여수  0.152  1.0  5.99
# 15         제주도  코스, 맛집, 여수  0.152  1.0  5.99
# 16     맛집, 제주도      코스, 여수  0.152  1.0  5.99
# 17     코스, 제주도      맛집, 여수  0.152  1.0  5.99
# 18         제주도  한곳, 맛집, 여수  0.152  1.0  5.99
# 19     맛집, 제주도      한곳, 여수  0.152  1.0  5.99
# 20     한곳, 제주도      맛집, 여수  0.152  1.0  5.99
# 21         제주도  주가, 여수, 전주  0.152  1.0  5.99
# 22     제주도, 전주      주가, 여수  0.152  1.0  5.99
# 23         제주도  코스, 여수, 전주  0.152  1.0  5.99
# 24     제주도, 전주      코스, 여수  0.152  1.0  5.99
# 25         제주도  한곳, 여수, 전주  0.152  1.0  5.99
# 26     제주도, 전주      한곳, 여수  0.152  1.0  5.99
# 27         제주도  코스, 주가, 여수  0.152  1.0  5.99
# 28     주가, 제주도      코스, 여수  0.152  1.0  5.99
# 29     코스, 제주도      주가, 여수  0.152  1.0  5.99
# 30         제주도  한곳, 주가, 여수  0.152  1.0  5.99
# 31     주가, 제주도      한곳, 여수  0.152  1.0  5.99
# 32     한곳, 제주도      주가, 여수  0.152  1.0  5.99
# 33         제주도  한곳, 코스, 여수  0.152  1.0  5.99
# 34     코스, 제주도      한곳, 여수  0.152  1.0  5.99
# 35     한곳, 제주도      코스, 여수  0.152  1.0  5.99
# 36      주가, 국내  맛집, 여수, 전주  0.157  1.0  5.99
# 37  주가, 국내, 전주      맛집, 여수  0.157  1.0  5.99
# 38      한곳, 국내  맛집, 여수, 전주  0.157  1.0  5.99
# 39  한곳, 국내, 전주      맛집, 여수  0.157  1.0  5.99
# 40      주가, 국내  코스, 맛집, 여수  0.157  1.0  5.99
# 41  주가, 맛집, 국내      코스, 여수  0.157  1.0  5.99
# 42  코스, 주가, 국내      맛집, 여수  0.157  1.0  5.99
# 43      주가, 국내  한곳, 맛집, 여수  0.157  1.0  5.99
# 44      한곳, 국내  주가, 맛집, 여수  0.157  1.0  5.99
# 45  주가, 맛집, 국내      한곳, 여수  0.157  1.0  5.99
# 46  한곳, 맛집, 국내      주가, 여수  0.157  1.0  5.99
# 47  한곳, 주가, 국내      맛집, 여수  0.157  1.0  5.99
# 48      한곳, 국내  코스, 맛집, 여수  0.157  1.0  5.99
# 49  한곳, 맛집, 국내      코스, 여수  0.157  1.0  5.99
# 50  한곳, 코스, 국내      맛집, 여수  0.157  1.0  5.99
# 51      주가, 국내  코스, 여수, 전주  0.157  1.0  5.99
# 52  주가, 국내, 전주      코스, 여수  0.157  1.0  5.99
# 53      주가, 국내  한곳, 여수, 전주  0.157  1.0  5.99
# 54      한곳, 국내  주가, 여수, 전주  0.157  1.0  5.99
# 55  주가, 국내, 전주      한곳, 여수  0.157  1.0  5.99
# 56  한곳, 국내, 전주      주가, 여수  0.157  1.0  5.99
# 57      한곳, 국내  코스, 여수, 전주  0.157  1.0  5.99
# 58  한곳, 국내, 전주      코스, 여수  0.157  1.0  5.99
# 59      주가, 국내  한곳, 코스, 여수  0.157  1.0  5.99
